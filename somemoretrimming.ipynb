# %%
import pandas as pd

# %% [markdown]
# Do one vote dataframe per congress. Consider both houses separately

# %%
import pickle

# %%
import numpy as np

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA

# %%
class StemTokenizer(object):
     def __init__(self):
         self.ps = PorterStemmer()
         self.reg = reg = re.compile(r'['+ string.punctuation + r'0-9]+')
         self.stemmed_to_orig = {}



     def __call__(self, doc):
         words = word_tokenize(doc)
         words = [word for word in words if self.reg.search(word) is None]

         stemmed_w = []

         for word in words:
             stemmed = self.ps.stem(word)
             stemmed_w.append(stemmed)
             self.stemmed_to_orig[stemmed] = word

         return stemmed_w

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
with open("./2n3ngramsdtmat.pkl", "rb") as f:
    dtmat = pickle.load(f)

# %%
dtmat.shape
# Out:
# (1663, 49311)

# %%
with open("./cvect2n3.pkl", "rb") as f:
    cvect = pickle.load(f)
# Out:
# /home/brocas/anaconda2/lib/python2.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator CountVectorizer from version 0.19.1 when using version 0.18.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
cvect.get_feature_names()
# Out:
# [u'aa strike',
#  u'abil depart',
#  u'abil effect',
#  u'abil meet',
#  u'abil provid',
#  u'abil secretari',
#  u'abil state',
#  u'abil unit',
#  u'abil unit state',
#  u'abl meet',
#  u'abort provid',
#  u'abus act',
#  u'abus b',
#  u'abus child',
#  u'abus mental',
#  u'abus mental health',
#  u'abus prevent',
#  u'abus sec',
#  u'abus treatment',
#  u'academ achiev',
#  u'academ institut',
#  u'academ program',
#  u'academ year',
#  u'academi scienc',
#  u'academi scienc conduct',
#  u'academi scienc shall',
#  u'academi sec',
#  u'academi shall',
#  u'academi shall remain',
#  u'acceler develop',
#  u'accept account',
#  u'accept account principl',
#  u'accept ani',
#  u'accept contribut',
#  u'accept donat',
#  u'accept fund',
#  u'accept gift',
#  u'accept level',
#  u'accept offer',
#  u'accept payment',
#  u'accept reimburs',
#  u'accept secretari',
#  u'accept thi',
#  u'accept use',
#  u'access afford',
#  u'access ani',
#  u'access appropri',
#  u'access b',
# ...

# %%
def get_total_wcount(dt_mat):
    return dt_mat.sum(axis=0).tolist()

# %%
def get_perdoc_wcount(dt_mat):
    return dt_mat.sum(axis=1).tolist()

# %%
good_inds = [tot_sum > 33 for tot_sum in get_total_wcount(dtmat)[0]]

# %%
len(good_inds)
# Out:
# 49311

# %%
gdtmat = dtmat[:,np.array(good_inds)]

# %%
gdtmat.shape
# Out:
# (1663, 49014)

# %%
with open("finaldtmat.pkl", "wb") as f:
    pickle.dump(gdtmat, f)

# %%
negmat.shape
# Out:
# (1663, 49311)

# %%
#mlda = LDA(n_components=32, learning_method='online', evaluate_every=3, total_samples=1663, n_jobs=-1, verbose=1, random_state=123)
# Out:
#   File "<ipython-input-34-a14a2e5bd346>", line 1
#     mlda = LDA(n_components=)
#                             ^
# SyntaxError: invalid syntax
