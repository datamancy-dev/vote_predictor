# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.feature_extraction.text import CountVectorizer

# %%
import string

# %%
with open("./all_sbills.pkl", "rb") as f:
    allsbills = pickle.load(f)

# %%
print(allsbills.text[2])
# Out:
# [Congressional Bills 109th Congress]
# [From the U.S. Government Publishing Office]
# [H.R. 4 Placed on Calendar Senate (PCS)]
#
#
#                                                        Calendar No. 561
# 109th CONGRESS
#   2d Session
#                                  H. R. 4
#
#
# _______________________________________________________________________
#
#
#                    IN THE SENATE OF THE UNITED STATES
#
#                              July 31, 2006
#
# Received; deemed read the first time on July 28 (legislative day, July
#            26), 2006, pursuant to the order of July 28, 2006
#
#                              July 31, 2006
#
#             Read the second time and placed on the calendar
#
# _______________________________________________________________________
#
#                                  AN ACT
#
#
#
# To provide economic security for all Americans, and for other purposes.
#
#     Be it enacted by the Senate and House of Representatives of the
# ...

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Out:
# True
